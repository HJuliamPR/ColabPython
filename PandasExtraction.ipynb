# %% [markdown]
# <a href="https://colab.research.google.com/github/HJuliamPR/ColabPython/blob/main/PandasExtraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Leyendo CSV

# %% [markdown]
# ## importando Archivos CSV

# %%
import pandas as pd

# %%
# Pandas automatically transform this file in a dataframe
DataStore = pd.read_csv("/content/drive/MyDrive/GoogleColab/superstore_data.csv")

# %%
DataStore.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %% [markdown]
# ## Parámetros función read_csv

# %%
DataStoreNrows = pd.read_csv("/content/drive/MyDrive/GoogleColab/superstore_data.csv", nrows=5)

# %% [markdown]
# # LEYENDO EXCEL

# %%
FilePathCO2 = '/content/drive/MyDrive/GoogleColab/emisiones_CO2.xlsx'
# DataCO2 = pd.read_excel(FilePathCO2, sheet_name=['emisiones_C02', 'emisiones_percapita', 'fuentes'])
DataCO2 = pd.read_excel(FilePathCO2, sheet_name='emisiones_C02', usecols='A:D')

# %%
DataCO2.columns
# Out:
# Index(['País', 'ISO 3166-1 alpha-3', 'Año', 'Total'], dtype='object')

# %%
# With this method I import the excel file as an object.
ExcelCO2 = pd.ExcelFile("/content/drive/MyDrive/GoogleColab/emisiones_CO2.xlsx")
ExcelCO2.sheet_names
# Out:
# ['emisiones_C02', 'emisiones_percapita', 'fuentes']

# %%
DataCO2.to_excel('/content/drive/MyDrive/GoogleColab/DataCO2.xlsx', index=False)

# %%
DataCO2.keys()

# DataCO2_2 = DataCO2['emisiones_C02']
# DataPercapita = DataCO2['emisiones_percapita']
# DataFuentes = DataCO2['fuentes']
# print( type(DataCO2_2), type(DataPercapita), type(DataFuentes))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'emisiones_C02'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-21-2367914161.py in <cell line: 0>()
#       1 DataCO2.keys()
#       2
# ...

# %%
DataCO2_2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-22-1023173129.py in <cell line: 0>()
# ----> 1 DataCO2_2.head()
#
# NameError: name 'DataCO2_2' is not defined

# %%
DataPercapita.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-23-2809799459.py in <cell line: 0>()
# ----> 1 DataPercapita.head()
#
# NameError: name 'DataPercapita' is not defined

# %%
DataFuentes.head()

# %% [markdown]
# ## Leyendo desde Google Sheet

# %%
Google_sheet_Id =  '1mpLME14xrr27mCEiQvdwsrRZVfGhJBXC2gohQHUFe0g'
# gviz/tq?tgx=out:csv&sheet ->
sheetName = 'emisiones_percapita'
UrlGoogleSheet = f"https://docs.google.com/spreadsheets/d/{Google_sheet_Id}/gviz/tq?tqx=out:csv&sheet"
UrlPercapita = f"https://docs.google.com/spreadsheets/d/{Google_sheet_Id}/gviz/tq?tqx=out:csv&sheet={sheetName}"

# %%
DataCO2_Google = pd.read_csv(UrlGoogleSheet)
DataPercapita_Google = pd.read_csv(UrlPercapita)

# %%
DataCO2_Google.head()
# Out:
#          País ISO 3166-1 alpha-3   Año Total Carbón Aceite  Gas Cemento Quema  \
# 0  Afganistán                AFG  1750     0    NaN    NaN  NaN     NaN   NaN
# 1  Afganistán                AFG  1751     0    NaN    NaN  NaN     NaN   NaN
# 2  Afganistán                AFG  1752     0    NaN    NaN  NaN     NaN   NaN
# 3  Afganistán                AFG  1753     0    NaN    NaN  NaN     NaN   NaN
# 4  Afganistán                AFG  1754     0    NaN    NaN  NaN     NaN   NaN
#
#   Otros Per Capita
# 0   NaN        NaN
# 1   NaN        NaN
# 2   NaN        NaN
# 3   NaN        NaN
# 4   NaN        NaN

# %%
DataPercapita_Google.head()
# Out:
#          País ISO 3166-1 alpha-3   Año Total Carbón Aceite  Gas Cemento Quema  \
# 0  Afganistán                AFG  1750   NaN    NaN    NaN  NaN     NaN   NaN
# 1  Afganistán                AFG  1751   NaN    NaN    NaN  NaN     NaN   NaN
# 2  Afganistán                AFG  1752   NaN    NaN    NaN  NaN     NaN   NaN
# 3  Afganistán                AFG  1753   NaN    NaN    NaN  NaN     NaN   NaN
# 4  Afganistán                AFG  1754   NaN    NaN    NaN  NaN     NaN   NaN
#
#    Otros
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %% [markdown]
# # Leyendo JSON

# %%
DataPacientes = pd.read_json("/content/drive/MyDrive/GoogleColab/pacientes.json")
DataPacientes.head(3)
# Out:
#    ID_paciente Enfermedad_corazon    IMC Fumador Consumo_alcohol AVC  \
# 0            0                 No  16.60      Sí              No  No
# 1            1                 No  20.34      No              No  Sí
# 2            2                 No  26.58      Sí              No  No
#
#    Salud_fisica  Salud_mental Dificultad_caminar Sexo_biologico Rango_edad  \
# 0             3            30                 No       Femenino      55-59
# 1             0             0                 No       Femenino     80 ó +
# 2            20            30                 No      Masculino      65-69
#
#      Raza Diabetes Actividad_fisica Salud_general  Horas_sueño Asma  \
# 0  Blanca       Sí               Sí     Muy buena            5   Sí
# 1  Blanca       No               Sí     Muy buena            7   No
# 2  Blanca       Sí               Sí     Razonable            8   Sí
#
#   Enfermedad_renal Cancer_piel
# 0               No          Sí
# 1               No          No
# ...

# %%
DataPacientes2 = pd.read_json("/content/drive/MyDrive/GoogleColab/pacientes_2.json")
DataPacientes2.head(3)
# Out:
#                                  Investigación   Año  \
# 0  Indicadores clave de enfermedades cardíacas  2020
# 1  Indicadores clave de enfermedades cardíacas  2020
# 2  Indicadores clave de enfermedades cardíacas  2020
#
#                                            Pacientes
# 0  {'ID': '01', 'Rango_edad': '55-59', 'Sexo_biol...
# 1  {'ID': '02', 'Rango_edad': '80 ó +', 'Sexo_bio...
# 2  {'ID': '03', 'Rango_edad': '65-69', 'Sexo_biol...

# %%
pd.json_normalize(DataPacientes2['Pacientes'])
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0  01      55-59          Mujer  Blanca  16.60      Sí              No
# 1  02     80 ó +          Mujer  Blanca  20.34      No              No
# 2  03      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]

# %% [markdown]
# # DESAFIO

# %%
# DataStoreColumns = pd.read_csv("/content/drive/MyDrive/GoogleColab/superstore_data.csv", \
#                                usecols=['Id', 'Year_Birth', 'Income'])
DataStoreColumns = pd.read_csv("/content/drive/MyDrive/GoogleColab/superstore_data.csv", \
                               usecols=[0, 1, 4])
DataStoreColumns

# %%
DataStoreColumns.to_csv('/content/drive/MyDrive/GoogleColab/DataStoreColumns.csv', index=False)

# %%
DataTest = pd.read_csv('/content/drive/MyDrive/GoogleColab/DataStoreColumns.csv')
DataTest

# %%
DataSUS = pd.read_csv('/content/drive/MyDrive/GoogleColab/datos_sus.csv', encoding='ISO-8859-1', sep=";", skiprows=3, skipfooter=9, engine='python')
DataSUS
