# %% [markdown]
# <a href="https://colab.research.google.com/github/HJuliamPR/ColabPython/blob/main/inmuebles_cdmx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Pandas**
#
# ## Importar la base de datos.

# %%
import pandas as pd

url = "https://gist.githubusercontent.com/ahcamachod/a572cfcc2527046db93101f88011b26e/raw/ffb13f45a79d31223e645611a119397dd127ee3c/alquiler.csv"

Data = pd.read_csv(url, sep=";")
Data.head(10)
Data.tail(10)
Data.sample(10)
# Out:
#                              Tipo               Colonia  Habitaciones  \
# 21200                Departamento             Del Valle             3
# 10021     Conjunto Comercial/Sala              Coyoacán             0
# 18744                    Cocineta             Nativitas             1
# 17356                Departamento                  Roma             1
# 23247  Tienda en Centro Comercial              Santa Fe             0
# 8929        Departamento en Hotel  Bosques de las Lomas             2
# 18339     Conjunto Comercial/Sala      Centro Histórico             0
# 3093                 Departamento              Santa Fe             3
# 20432                Departamento               Tláhuac             2
# 7335                 Departamento                  Roma             3
#
#        Garages  Suites  Area    Valor  Condominio  Impuesto
# 21200        0       0   150   9800.0      4060.0     700.0
# 10021        1       0    31   7700.0      2597.0     577.5
# 18744        0       0    21   2450.0       626.5       NaN
# 17356        1       1    45  13300.0         NaN       NaN
# 23247        1       0    62  17500.0     16964.5    1890.0
# 8929         1       1    95  11550.0      6300.0    1050.0
# 18339        0       0    32   2800.0      1480.5     273.0
# 3093         2       3   145  11200.0      6300.0       NaN
# 20432        1       0    45   2100.0         NaN       NaN
# 7335         2       1   110  19250.0         NaN       NaN

# %%
type(Data)
# Out:
# pandas.core.frame.DataFrame
